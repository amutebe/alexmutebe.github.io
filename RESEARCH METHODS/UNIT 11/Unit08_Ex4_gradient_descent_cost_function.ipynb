# %% [markdown]
# <a href="https://colab.research.google.com/github/amutebe/alexmutebe.github.io/blob/main/UNIT%208/Unit08_Ex4_gradient_descent_cost_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Calculating cost with gradient descent and learning rate
# - Change the iteration and learning rate vaules and see the impact on cost.
# - Low iteration values with high learning rate (i.e. big steps) may lead to miss the global minimum
# - Goal is to reach minimum cost with minimum iteration

# %% [markdown]
# ![cost_function.png](attachment:cost_function.png)

# %%
# code credit:codebasics https://codebasics.io/coming-soon

import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0  #Initialize the slope (m_curr) and y-intercept (b_curr) to zero.

    #Specify the number of iterations and learning rate
    iterations = 400     #change value
    n = len(x)
    learning_rate = 0.02  #change value

    for i in range(iterations):

        y_predicted = m_curr * x + b_curr #Calculate the predicted y-values using the current slope and y-intercept.

        cost = (1/n) * sum([val**2 for val in (y-y_predicted)]) #Compute the cost (mean squared error) between the predicted y-values and the actual y-values.

        #Calculate the gradients (md for slope and bd for y-intercept)
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)

        # Update the slope and y-intercept using the gradients and learning rate.
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 1.24, b 0.36, cost 89.0 iteration 0
# m 1.8912, b 0.5568, cost 25.3616 iteration 1
# m 2.232256, b 0.667584, cost 7.694359040000001 iteration 2
# m 2.40995328, b 0.73300992, cost 2.7832300789760005 iteration 3
# m 2.5016126464, b 0.7744951296, cost 1.4117625182879754 iteration 4
# m 2.547963666432, b 0.803321806848, cost 1.0225913197820489 iteration 5
# m 2.57046103638016, b 0.82543329460224, cost 0.9061020411503913 iteration 6
# m 2.580406185020621, b 0.8439606384525312, cost 0.8653906318976792 iteration 7
# m 2.583752186997244, b 0.8605534707119554, cost 0.8458189807137511 iteration 8
# m 2.583634808233022, b 0.8760810694438079, cost 0.8322246831340234 iteration 9
# m 2.581705764277235, b 0.891001649678093, cost 0.8203990003422286 iteration 10
# m 2.5788350300338805, b 0.9055568919777011, cost 0.8091726163869117 iteration 11
# m 2.5754807897816487, b 0.9198744126945274, cost 0.798219608661616 iteration 12
# ...
